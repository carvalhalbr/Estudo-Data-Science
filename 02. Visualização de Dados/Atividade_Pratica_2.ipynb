# %% [markdown]
# # Atividade Pratica 2

# %%
import pandas as pd 
import seaborn as srn 
import statistics  as sts
import numpy as np
import matplotlib.pyplot as plt

# %%
#importar dados
dataset = pd.read_csv("E:\\DATA_SCIENCE\\Data-Science\\Python\\02. Visualização de Dados\\src\\dados\\dados.csv", sep=";")
#visulizar
dataset.head()
# Out:
#    CODIGO               MUNICIPIO       PIB  VALOREMPENHO
# 0     106   SANTANA DO LIVRAMENTO  12240.76    1088666.10
# 1     113            SANTO ANGELO  16575.82     800669.92
# 2     118  SAO FRANCISCO DE ASSIS  12037.61     466122.80
# 3      13         CACAPAVA DO SUL  13674.54     485535.86
# 4     120             SAO GABRIEL  19912.38     533719.86

# %%
#tamanho
dataset.shape # (linhas, colunas)
# Out:
# (187, 4)

# %%
agrupado = dataset.groupby(['MUNICIPIO']).size()
agrupado
# Out:
# MUNICIPIO
# AGUDO                         1
# AJURICABA                     1
# ALECRIM                       1
# ALMIRANTE TAMANDARE DO SUL    1
# ALTO FELIZ                    1
#                              ..
# VERA CRUZ                     1
# VIADUTOS                      1
# VICTOR GRAEFF                 1
# VILA MARIA                    1
# VILA NOVA DO SUL              1
# Length: 177, dtype: int64

# %%
agrupado = dataset.sort_values('MUNICIPIO').head(10)
agrupado
agrupado.plot.bar(x='MUNICIPIO',y='PIB', color = 'orange')
agrupado.plot.bar(x='MUNICIPIO',y='VALOREMPENHO', color = 'orange')
# Out:
# <AxesSubplot:xlabel='MUNICIPIO'>

# %%
srn.distplot(dataset.PIB, bins = 10, axlabel = 'PIB', hist_kws={'edgecolor': 'black', 'color': '#ff9539' }, kde_kws={'color': '#FF7600'}).set_title('PIB')
# Out:
# Text(0.5, 1.0, 'PIB')

# %%
srn.distplot(dataset.VALOREMPENHO, bins = 10, axlabel = 'VALOREMPENHO',hist_kws={'edgecolor': 'black', 'color': '#ff9539' }, kde_kws={'color': '#FF7600'}).set_title('VALOREMPENHO')
# Out:
# Text(0.5, 1.0, 'VALOREMPENHO')
